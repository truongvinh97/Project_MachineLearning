# %%
import pandas as pd
import random
questions = {
"strong": ["Do ye like yer drinks strong?"],
"salty": ["Do ye like it with a salty tang?"],
"bitter": ["Are ye a lubber who likes it bitter?"],
"sweet": ["Would ye like a bit of sweetness with yer poison?"],
"fruity":["Are ye one for a fruity finish?"],
}
ingredients = {
"strong": ["glug of rum", "slug of whisky", "splash of gin"],
"salty": ["olive on a stick", "salt-dusted rim", "rasher of bacon"],
"bitter": ["shake of bitters", "splash of tonic", "twist of lemon peel"],
"sweet": ["sugar cube", "spoonful of honey", "spash of cola"],
"fruity": ["slice of orange", "dash of cassis", "cherry on top"],
}
data1 = pd.DataFrame(questions).melt(value_name='questions')
data2 = pd.DataFrame(ingredients).melt(value_name='ingredients')
data1.head()
data2.head()
# Out:
# Do ye like yer drinks strong?
# 1
# splash of gin

# %%
data1.head()
# Out:
#   variable                                          questions
# 0   strong                      Do ye like yer drinks strong?
# 1    salty                   Do ye like it with a salty tang?
# 2   bitter               Are ye a lubber who likes it bitter?
# 3    sweet  Would ye like a bit of sweetness with yer poison?
# 4   fruity                    Are ye one for a fruity finish?

# %%
data2.head(15)
# Out:
#    variable          ingredients
# 0    strong          glug of rum
# 1    strong       slug of whisky
# 2    strong        splash of gin
# 3     salty     olive on a stick
# 4     salty      salt-dusted rim
# 5     salty      rasher of bacon
# 6    bitter     shake of bitters
# 7    bitter      splash of tonic
# 8    bitter  twist of lemon peel
# 9     sweet           sugar cube
# 10    sweet    spoonful of honey
# 11    sweet        spash of cola
# 12   fruity      slice of orange
# 13   fruity       dash of cassis
# 14   fruity        cherry on top

# %%
c = 0
for i in data1['questions']:
    print(i)
    a = input()
    if (a == 'yes'):
        print("You should choose:")
        if (data1['variable'][c] == "strong"):
            d = random.randrange(0, 3)
            print(data2['ingredients'][d])

        if (data1['variable'][c] == 'salty'):
            d = random.randrange(3, 6)
            print(data2['ingredients'][d])

        if (data1['variable'][c] == 'bitter'):
            d = random.randrange(6, 9)
            print(data2['ingredients'][d])

        if (data1['variable'][c] == 'sweet'):
            d = random.randrange(9, 12)
            print(data2['ingredients'][d])

        if (data1['variable'][c] == 'fruity'):
            d = random.randrange(12, 15)
            print("data2['ingredients'][d]")

        break
    else:
        c += 1
        continue
# Out:
# Do ye like yer drinks strong?
# no
# Do ye like it with a salty tang?
# no
# Are ye a lubber who likes it bitter?
# yes
# You should choose:
# shake of bitters
